# %%
# !pip install bs4
# !pip install sentence-transformers faiss-cpu transformers langdetect deep-translator google-genai streamlit
# Out:
# Requirement already satisfied: bs4 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (0.0.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from bs4) (4.13.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from beautifulsoup4->bs4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from beautifulsoup4->bs4) (4.12.2)
# Requirement already satisfied: sentence-transformers in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (4.1.0)
# Requirement already satisfied: faiss-cpu in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (1.11.0)
# Requirement already satisfied: transformers in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (4.52.4)
# Requirement already satisfied: langdetect in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (1.0.9)
# Requirement already satisfied: deep-translator in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (1.11.4)
# Requirement already satisfied: google-genai in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (1.22.0)
# Collecting streamlit
#   Downloading streamlit-1.46.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: tqdm in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from sentence-transformers) (2.6.0)
# Requirement already satisfied: scikit-learn in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from sentence-transformers) (1.7.0)
# Requirement already satisfied: scipy in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from sentence-transformers) (1.15.2)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from sentence-transformers) (0.33.1)
# Requirement already satisfied: Pillow in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from sentence-transformers) (11.1.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from sentence-transformers) (4.12.2)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from faiss-cpu) (24.2)
# Requirement already satisfied: filelock in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from transformers) (3.17.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from transformers) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: six in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from langdetect) (1.17.0)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from deep-translator) (4.13.4)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from google-genai) (4.8.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from google-genai) (2.38.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from google-genai) (2.10.6)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.3 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from google-genai) (8.5.0)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from google-genai) (15.0.1)
# Collecting altair<6,>=4.0 (from streamlit)
#   Downloading altair-5.5.0-py3-none-any.whl.metadata (11 kB)
# Collecting blinker<2,>=1.5.0 (from streamlit)
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: cachetools<7,>=4.0 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from streamlit) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from streamlit) (8.1.8)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from streamlit) (2.2.3)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from streamlit) (5.29.3)
# Collecting pyarrow>=7.0 (from streamlit)
#   Downloading pyarrow-20.0.0-cp312-cp312-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from streamlit) (0.10.2)
# Collecting watchdog<7,>=2.1.5 (from streamlit)
#   Downloading watchdog-6.0.0-py3-none-win_amd64.whl.metadata (44 kB)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Downloading GitPython-3.1.44-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from streamlit) (6.5.1)
# Requirement already satisfied: jinja2 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.5)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Collecting narwhals>=1.14.2 (from altair<6,>=4.0->streamlit)
#   Downloading narwhals-1.44.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: idna>=2.8 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (1.3.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator) (2.7)
# Requirement already satisfied: colorama in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (4.9)
# Requirement already satisfied: certifi in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2022.7.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from pydantic<3.0.0,>=2.0.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from pydantic<3.0.0,>=2.0.0->google-genai) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from requests->transformers) (1.26.20)
# Requirement already satisfied: networkx in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: setuptools in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from torch>=1.11.0->sentence-transformers) (75.8.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.23.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\royal\anaconda3\envs\yolo-env1\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-genai) (0.6.1)
# Downloading streamlit-1.46.0-py3-none-any.whl (10.1 MB)
#    ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#    --------- ------------------------------ 2.4/10.1 MB 11.2 MB/s eta 0:00:01
#    ------------------- -------------------- 5.0/10.1 MB 11.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.3/10.1 MB 11.6 MB/s eta 0:00:01
#    ---------------------------------------  10.0/10.1 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------- 10.1/10.1 MB 11.6 MB/s eta 0:00:00
# Downloading altair-5.5.0-py3-none-any.whl (731 kB)
#    ---------------------------------------- 0.0/731.2 kB ? eta -:--:--
#    --------------------------------------- 731.2/731.2 kB 10.0 MB/s eta 0:00:00
# Using cached blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading GitPython-3.1.44-py3-none-any.whl (207 kB)
# Downloading pyarrow-20.0.0-cp312-cp312-win_amd64.whl (25.7 MB)
#    ---------------------------------------- 0.0/25.7 MB ? eta -:--:--
#    --- ------------------------------------ 2.4/25.7 MB 12.2 MB/s eta 0:00:02
#    ------- -------------------------------- 4.7/25.7 MB 11.9 MB/s eta 0:00:02
#    ----------- ---------------------------- 7.3/25.7 MB 11.6 MB/s eta 0:00:02
#    --------------- ------------------------ 9.7/25.7 MB 11.8 MB/s eta 0:00:02
#    ------------------- -------------------- 12.3/25.7 MB 11.9 MB/s eta 0:00:02
#    ----------------------- ---------------- 14.9/25.7 MB 11.7 MB/s eta 0:00:01
#    -------------------------- ------------- 17.3/25.7 MB 11.9 MB/s eta 0:00:01
#    ------------------------------- -------- 19.9/25.7 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 22.3/25.7 MB 11.7 MB/s eta 0:00:01
#    -------------------------------------- - 24.9/25.7 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------- 25.7/25.7 MB 11.6 MB/s eta 0:00:00
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    ------------- -------------------------- 2.4/6.9 MB 11.2 MB/s eta 0:00:01
#    --------------------------- ------------ 4.7/6.9 MB 11.4 MB/s eta 0:00:01
#    ---------------------------------------- 6.9/6.9 MB 11.5 MB/s eta 0:00:00
# Downloading watchdog-6.0.0-py3-none-win_amd64.whl (79 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading narwhals-1.44.0-py3-none-any.whl (365 kB)
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Installing collected packages: watchdog, smmap, pyarrow, narwhals, blinker, pydeck, gitdb, gitpython, altair, streamlit
# Successfully installed altair-5.5.0 blinker-1.9.0 gitdb-4.0.12 gitpython-3.1.44 narwhals-1.44.0 pyarrow-20.0.0 pydeck-0.9.1 smmap-5.0.2 streamlit-1.46.0 watchdog-6.0.0

# %%
from bs4 import BeautifulSoup
from urllib.parse import urlparse, urljoin
import requests, html, json, tldextract
from deep_translator import GoogleTranslator, exceptions

# --- Paraphrasing with FLAN-T5 via Hugging Face Inference API ---
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
import torch

# Load the model once
tokenizer = AutoTokenizer.from_pretrained("google/flan-t5-base")
model = AutoModelForSeq2SeqLM.from_pretrained("google/flan-t5-base")

def flan_paraphrase(text):
    prompt = f"Paraphrase this in a friendly, natural tone: {text}"
    inputs = tokenizer(prompt, return_tensors="pt", truncation=True)
    outputs = model.generate(
        **inputs,
        max_length=512,
        num_beams=5,
        temperature=1.0,
        top_k=50,
        top_p=0.95
    )
    return tokenizer.decode(outputs[0], skip_special_tokens=True)



# --- Safe Translation with Deep Translator Fallback ---
def safe_translate(text, target='hi'):
    try:
        return GoogleTranslator(source='auto', target=target).translate(text)
    except exceptions.TranslationNotFound:
        print(f"⚠️ Could not translate: {text}")
        return text
    except Exception as e:
        print(f"❌ Translation error: {e}")
        return text

# --- CRAWLER + FAQ PARSER ---
BASE_URL = "https://jupiter.money"
visited = set()
faq_data = {}

def extract_topics_from_url(url):
    path = urlparse(url).path.lower()
    keywords = ["credit-card", "credit-cards", "payment", "payments", "account", "accounts", "upi", "bill", "bills",
                "magic-spends", "rewards", "loan", "loans", "money", "invest"]
    topics = []
    for kw in keywords:
        if (f"/{kw}" in path or f"-{kw}" in path or f"{kw}-" in path or path.endswith(kw) or path.endswith(f"{kw}/")):
            topic = kw.replace("-", " ").rstrip("s").title()
            if topic not in topics:
                topics.append(topic)
    return topics or ["General"]

def is_internal(url):
    base = tldextract.extract(BASE_URL).domain
    link = tldextract.extract(url).domain
    return base == link or url.startswith("/")

def get_all_links(soup, base_url):
    links = set()
    for a in soup.find_all('a', href=True):
        full = urljoin(base_url, a['href'])
        if is_internal(full):
            p = urlparse(full)
            links.add(f"{p.scheme}://{p.netloc}{p.path}")
    return links

def clean_text(text):
    return ' '.join(html.unescape(text).split())

def extract_faq_from_page(url):
    try:
        res = requests.get(url, timeout=10)
        if res.status_code != 200:
            return {}
        soup = BeautifulSoup(res.text, 'html.parser')
    except:
        return {}

    items = soup.select('.faq-item')
    if not items:
        return {}

    section = "FAQs"
    for tag in ['h1', 'h2', 'h3']:
        h = soup.find(tag, string=lambda t: t and 'faq' in t.lower())
        if h:
            section = clean_text(h.get_text())
            break

    topics = extract_topics_from_url(url)
    qas = []
    for item in items:
        q_tag = item.select_one('.faq-header span')
        a_tag = item.select_one('.faq-answer')
        if q_tag and a_tag:
            q_text = clean_text(q_tag.get_text())
            a_text = clean_text(a_tag.get_text(separator=' '))
            qas.append({
                "question": q_text,
                "answer": a_text,
                "topics": topics
            })

    return {section: qas}

def crawl(url, max_depth=2, depth=0):
    if depth > max_depth or url in visited:
        return
    visited.add(url)
    print(f"Crawling: {url}")
    try:
        res = requests.get(url, timeout=10)
        soup = BeautifulSoup(res.text, 'html.parser')
    except:
        return

    page_faqs = extract_faq_from_page(url)
    for section, qas in page_faqs.items():
        faq_data.setdefault(section, [])
        for qa in qas:
            if qa not in faq_data[section]:
                faq_data[section].append(qa)

    for link in get_all_links(soup, url):
        crawl(link, max_depth, depth + 1)

# Run crawler
crawl(BASE_URL)

# Translate + Rephrase
for section in faq_data.values():
    for qa in section:
        q_en, a_en = qa["question"], qa["answer"]
        qa["answer"] = flan_paraphrase(a_en)
        qa["question_hi"] = safe_translate(q_en, 'hi')
        qa["answer_hi"] = safe_translate(a_en, 'hi')

# Save to JSON
with open("jupiter_faqs_multilingual.json", "w", encoding='utf-8') as f:
    json.dump(faq_data, f, ensure_ascii=False, indent=2)

print("✅ Done: Crawled, paraphrased, and translated.")
# Out:
# Crawling: https://jupiter.money
# Crawling: https://jupiter.money/pay-via-upi
# Crawling: https://jupiter.money/calculators/personal-loan-emi-calculator/
# Crawling: https://life.jupiter.money/
# Crawling: https://jupiter.money/edge-csb-rupay-credit-card/
# Crawling: https://jupiter.money/savings-account
# Crawling: https://jupiter.money/corporate-salary-account
# Crawling: https://jupiter.money/investments
# Crawling: https://jupiter.money/calculators/credit-card-emi-calculator/
# Crawling: https://jupiter.money/careers
# Crawling: https://jupiter.money/magic-spends
# Crawling: https://jupiter.money/
# Crawling: https://jupiter.money/calculators/employee-provident-fund-calculator/
# Crawling: https://jupiter.money/payments
# Crawling: https://jupiter.money/google-api-disclosure
# Crawling: https://jupiter.money/edge-visa-credit-card/
# Crawling: https://jupiter.money/contact-us/
# Crawling: https://jupiter.money/communication-guidelines
# Crawling: https://jupiter.money/terms-and-conditions/
# Crawling: https://jupiter.money/calculators/emi-calculator/
# Crawling: https://jupiter.money/privacy-policy
# Crawling: https://jupiter.money/digi-gold
# Crawling: https://jupiter.money/rewards
# Crawling: https://jupiter.money/blog/
# Crawling: https://jupiter.money/flexi-fd
# Crawling: https://jupiter.money/about-us
# Crawling: https://jupiter.money/pots
# Crawling: https://jupiter.money/fees-rates-charges
# Crawling: https://jupiter.money/recurring-deposits
# Crawling: https://jupiter.money/edge-plus-upi-rupay-credit-card/
# Crawling: https://jupiter.money/contact-us
# Crawling: https://jupiter.money/calculators/salary-calculator/
# Crawling: https://jupiter.money/grievance-redressal-policy
# Crawling: https://jupiter.money/calculators/
# Crawling: https://jupiter.money/calculators/home-loan-emi-calculator/
# Crawling: https://jupiter.money/bills-recharges
# Crawling: https://jupiter.money/loan-against-mutual-funds
# Crawling: https://jupiter.money/money
# Crawling: https://jupiter.money/calculators/public-provident-fund-calculator/
# Crawling: https://jupiter.money/pro-salary-account/
# Crawling: https://jupiter.money/loan
# Crawling: https://community.jupiter.money/
# Crawling: https://jupiter.money/mutual-funds
# Crawling: https://jupiter.money/calculators/national-pension-scheme-calculator/
# Crawling: https://web.jupiter.money/web-ob/apply-loan/start
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Crawling: https://web.jupiter.money/rupay-csb/web-ob/landing
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# ✅ Done: Crawled, paraphrased, and translated.
